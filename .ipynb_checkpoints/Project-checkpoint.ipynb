# %% [markdown]
# # Research Questions:
#
# 1. Did the Astros stealing signs have an effect on how they hit non-fastballs?
# 2. Did the Astros make better contact with pitches outside of the strike zone?
# 3. Other comparisions between the Astros players and the other players
# 4. Did the Astros sign stealing scandal help them lay off (not swing) pitches outside of the strike zone?
# 5. Even though there has already been significant photographic and video evidence of the Astros’ cheating, does this data show they had a significant advantage given their knowledge of what pitches were coming?

# %% [markdown]
# # Pitch Classification:
# - The 11 pitch types we have in our dataset are categorized into 3 types:
#     - Fastballs
#         - 2 - Seam Fastball
#         - 4 - Seam Fastball
#         - Cutter
#         - Sinker
#     - Offspeed
#         - Split Finger
#         - Changeup
#     - Breaking Balls
#         - Curveball
#         - Eephus
#         - Knuckle Curve
#         - Pitch Out
#         - Slider

# %% [markdown]
# # Key Attributes:
#    # zone
#    - The strike zone is represented by subzones 1-9
#    - Subzones 11-14 represent spots for balls outside of the strike zone
#
# <img src = 'https://baseballsavant.mlb.com/sections/statcast_search_v2/images/zones.png' />
#
#    # launch_speed_angle
#    - The quality of contact the batter makes with the ball
#
# <img src = 'https://baseballsavant.mlb.com/sections/statcast_search_v2/images/speed-angle.png' />
#
# - Additional information regarding the key attributes of this dataset are found in the [data dictionary](https://baseballsavant.mlb.com/csv-docs).

# %% [markdown]
# # Data:
# - Our data comes from the [BaseballSavant](https://baseballsavant.mlb.com/statcast_search?hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&stadium=2392&hfBBL=&hfNewZones=&hfGT=R%7C&hfC=&hfSea=2017%7C&hfSit=&player_type=batter&hfOuts=&opponent=&pitcher_throws=&batter_stands=&hfSA=&game_date_gt=&game_date_lt=&hfInfield=&team=&position=&hfOutfield=&hfRO=&home_road=&hfFlag=&hfPull=&metric_1=&hfInn=&min_pitches=0&min_results=0&group_by=venue&sort_col=pitches&player_event_sort=h_launch_speed&sort_order=desc&min_pas=0#results) website.
# - This houses MLB's Statcast database, which tracks the ball's movement during every pitch and play.

# %%
#import packages to use for analysis
import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# reading the csv and loading it to source_data variable
# we do not have an index column 
# low_memory is needed because the file contains a lot of floats
source_data = pd.read_csv('2017_MLB_Data.csv', low_memory=False)

# %%
# collect number of rows and columns
rows = source_data.shape[0]
columns = source_data.shape[1]

#print out the rows and columns of the data
print('Rows: ', rows)
print('Columns: ', columns)
# Out:
# Rows:  22695
# Columns:  89

# %%
# display column's missing data as a ratio
source_data.isna().mean().round(4) * 100
# Out:
# pitch_type               0.14
# game_date                0.00
# release_speed            0.23
# release_pos_x            0.23
# release_pos_z            0.23
#                          ...
# post_home_score          0.00
# post_bat_score           0.00
# post_fld_score           0.00
# if_fielding_alignment    0.26
# of_fielding_alignment    0.26
# Length: 89, dtype: float64

# %%
# drop columns that have more than 50% cells missing
drop_cols = source_data.columns[source_data.isnull().mean()>0.5]
source_data.drop(drop_cols, axis=1)
source_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22695 entries, 0 to 22694
# Data columns (total 89 columns):
# pitch_type                         22664 non-null object
# game_date                          22695 non-null object
# release_speed                      22643 non-null float64
# release_pos_x                      22643 non-null float64
# release_pos_z                      22643 non-null float64
# player_name                        22695 non-null object
# batter                             22695 non-null int64
# pitcher                            22695 non-null int64
# events                             5836 non-null object
# description                        22695 non-null object
# spin_dir                           0 non-null float64
# spin_rate_deprecated               0 non-null float64
# break_angle_deprecated             0 non-null float64
# break_length_deprecated            0 non-null float64
# zone                               22643 non-null float64
# ...

# %%
#Drop columns we don't need
#Since our dataset contains columns from a previous statistical method, in addition to other columns we will not need, we can remove them
source_data.drop(['release_pos_x', 'release_pos_z', 'fielder_2', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 'game_type', 'game_year', 'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 'post_fld_score', 'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated', 'umpire'],axis=1, inplace=True)

#Check the data types remaining in the dataset
source_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22695 entries, 0 to 22694
# Data columns (total 64 columns):
# pitch_type                         22664 non-null object
# game_date                          22695 non-null object
# release_speed                      22643 non-null float64
# player_name                        22695 non-null object
# batter                             22695 non-null int64
# pitcher                            22695 non-null int64
# events                             5836 non-null object
# description                        22695 non-null object
# zone                               22643 non-null float64
# des                                5836 non-null object
# stand                              22695 non-null object
# p_throws                           22695 non-null object
# home_team                          22695 non-null object
# away_team                          22695 non-null object
# type                               22695 non-null object
# ...

# %%
# displays basic statistics of the given data
source_data.describe()
# Out:
#        release_speed         batter        pitcher          zone  \
# count   22643.000000   22695.000000   22695.000000  22643.000000
# mean       87.995235  513236.633091  543621.085217      9.624608
# std         6.012770  101091.776151   70691.374294      4.091088
# min        64.800000  134181.000000  112526.000000      1.000000
# 25%        83.300000  475174.000000  501789.000000      6.000000
# 50%        88.900000  514888.000000  571666.000000     11.000000
# 75%        92.900000  592743.000000  605242.000000     13.000000
# max       102.400000  664057.000000  664641.000000     14.000000
#
#        hit_location         balls       strikes         pfx_x         pfx_z  \
# count   5094.000000  22695.000000  22695.000000  22643.000000  22643.000000
# mean       5.069297      0.900815      0.876008     -0.335850      0.489119
# std        2.615730      0.975593      0.822673      0.898025      0.827920
# ...

# %%
#Create subsets of All-Star caliber players for analysis

# %%
Altuve=source_data[source_data['batter']==514888]

# %%
Bregman=source_data[source_data['batter']==608324]

# %%
Springer=source_data[source_data['batter']==543807]

# %%
Correa=source_data[source_data['batter']==621043]

# %%
Ramirez=source_data[source_data['batter']==608070]

# %%
Lindor=source_data[source_data['batter']==596019]

# %%
Pujols=source_data[source_data['batter']==405395]

# %%
Upton=source_data[source_data['batter']==457708]

# %%
Trout=source_data[source_data['batter']==545361]

# %%
Trumbo=source_data[source_data['batter']==444432]

# %%
Hosmer=source_data[source_data['batter']==543333]

# %%
Cabrera=source_data[source_data['batter']==408234]

# %%
Cruz=source_data[source_data['batter']==443558]

# %%
Betts=source_data[source_data['batter']==605141]

# %%
Judge=source_data[source_data['batter']==592450]

# %%
#Combine the player subsets into two (one consisting of Astros and one consisting of players from other teams in the league)
Astros=Altuve.append([Bregman, Springer, Correa])
League=Ramirez.append([Lindor, Pujols, Upton, Trout, Trumbo, Hosmer, Cabrera, Cruz, Betts, Judge])

# %%
#display information about our subset of Astros players
Astros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4289 entries, 0 to 22670
# Data columns (total 64 columns):
# pitch_type                         4278 non-null object
# game_date                          4289 non-null object
# release_speed                      4270 non-null float64
# player_name                        4289 non-null object
# batter                             4289 non-null int64
# pitcher                            4289 non-null int64
# events                             1119 non-null object
# description                        4289 non-null object
# zone                               4270 non-null float64
# des                                1119 non-null object
# stand                              4289 non-null object
# p_throws                           4289 non-null object
# home_team                          4289 non-null object
# away_team                          4289 non-null object
# type                               4289 non-null object
# ...

# %%
#display information about our subset of players from the rest of the league
League.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 899 entries, 16463 to 10559
# Data columns (total 64 columns):
# pitch_type                         894 non-null object
# game_date                          899 non-null object
# release_speed                      892 non-null float64
# player_name                        899 non-null object
# batter                             899 non-null int64
# pitcher                            899 non-null int64
# events                             223 non-null object
# description                        899 non-null object
# zone                               892 non-null float64
# des                                223 non-null object
# stand                              899 non-null object
# p_throws                           899 non-null object
# home_team                          899 non-null object
# away_team                          899 non-null object
# type                               899 non-null object
# ...

# %%
# correlation chart for Astros
corr = source_data.loc[:,Astros.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))

# %%
# correlation chart for League
corr = source_data.loc[:,League.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))

# %%
# plots & displays a chart of given pitch quantities for the Astros players
Astros['pitch_name'].value_counts().plot(kind='bar', rot=0, figsize=(18,8), title='Count of Pitches Seen by Astros Players')

# %%
#Displays density information regarding the distance of balls based on horizontal movement
Astros.plot.hexbin(x='pfx_x', y='hit_distance_sc', gridsize=20, title='Astros')
League.plot.hexbin(x='pfx_x', y='hit_distance_sc', gridsize=20, title='League')

#Displays density information regarding the distance of balls based on vertical movement
Astros.plot.hexbin(x='pfx_z', y='hit_distance_sc', gridsize=20, title='Astros')
League.plot.hexbin(x='pfx_z', y='hit_distance_sc', gridsize=20, title='League')

# %%
# displays average hitting distance of each pitch
Astros[['pitch_name', 'hit_distance_sc']].groupby(['pitch_name']).mean().plot(kind='barh', rot=0, title='Astros')
League[['pitch_name', 'hit_distance_sc']].groupby(['pitch_name']).mean().plot(kind='barh', rot=0, title='Rest of League')

# %%
#Displays how well pitches in each zone are being hit with an overlayed stripchart to highlight the location of the data for Astros players
sns.boxenplot('launch_speed_angle', 'zone', data=Astros,)
sns.stripplot('launch_speed_angle', 'zone', data=Astros, color='black')

# %%
#Displays how well pitches in each zone are being hit with an overlayed stripchart to highlight the location of the data for players in the rest of the league
sns.boxenplot('launch_speed_angle', 'zone', data=League)
sns.stripplot('launch_speed_angle', 'zone', data=League, color='black')

# %%
#Displays where pitches were hit to based on zone 
sns.boxenplot('zone', 'hit_location', data=Astros)

# %%
#Displays where pitches were hit to based on zone 
sns.boxenplot('zone', 'hit_location', data=League)

# %%
#Displays hit location based off of how well the pitch was hit
sns.boxplot('launch_speed_angle', 'hit_location', data=Astros)

# %%
#Displays hit location based off of how well the pitch was hit
sns.boxplot('launch_speed_angle', 'hit_location', data=League)

# %% [markdown]
# # Research Answers
# 1. Did the Astros stealing signs have an effect of how they hit non-fastballs?
#     - Based off of the analysis we did using the hex charts and bar graphs, we were able to tell that the Astros players were hitting non-fastballs/pitches that have a lot of movement, noticeably further than opposing teams.
#     - This could be an indication that the Astros players knew which pitches were coming when and that’s why they were able to hit these difficult pitches further
#
#
# 2. Did the Astros make better contact with pitches outside of the strike zone?
#     - Yes, the Astros made better contact with these pitches. This can be proved via the boxenplot graphs, which show that the Astros are making less weak-contact with pitches outside of the strike zone.
#     - Also, the Astros are making more solid contact across all the different zones. Meanwhile, other players are making solid contact through zones 3-11.
#
#
# 3. Did the Astros’ have harder contact overall as opposed to other players throughout the league?
#     - The Astros have more data in the outfield areas, pointing toward harder barreled balls and higher likelihood of a base hit or homerun.
#     - This demonstrates that the Astros players are driving the ball more often than opposing players in this dataset
#     - This could be evident that the Astros know what pitches are coming because they are making much more solid contact and driving more balls into the outfield, which in turn will help them score more runs
#
#
# 4. Did the Astros sign stealing scandal help them lay off (not swing) pitches outside of the strike zone?
#     - Based on our bar charts, the data does not support this assumption.
#     - We may need to compare more average players to the Astros team rather than the top tier All Star players in order to really tell the difference.
#
#
# 5. Even though there has already been significant photographic and video evidence of the Astros’ cheating, does this data show they had a significant advantage given their knowledge of what pitches were coming?
#     - There are some tells in this data that can show that the Astros could have potentially had an unfair advantage due to their sign stealing. However, the finds in our data are not significant enough to definitely determine that they did have an unfair advantage.
#     - In order to definitely determine whether or not the Astros did have an unfair advantage during the 2017 season, we would need more data, from previous years and future years.
