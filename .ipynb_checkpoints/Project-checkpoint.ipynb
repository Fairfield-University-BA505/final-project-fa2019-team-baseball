# %% [markdown]
# # Research Questions
#
# 1. Which pitches were being hit most by Silver Slugger and All Star caliber players at Minute Maid Park in 2017?
# 2. Which pitch zones were Silver Slugger and All Star caliber players hitting pitches from?
# 3. How often did Astros players swing at pitches outside of the strike zone?
# 4. How did Astros players perform on breaking / offspeed pitches compared players from other teams?
# 5. Other comparisons between Astros players and opposing players.

# %% [markdown]
# # Player Classification - Silver Slugger vs All Star
# - The __Silver Slugger__ is awarded to the top _hitter_ at each position.
# - __All Star__ players are voted on by fans based on their performance during the current season.
#     - Only top performing players are considered for the ballot.
#     - These players are usually well rounded and excel at both batting and fielding.

# %% [markdown]
# # Pitch Classification
# - Pitches are categorized into 11 types:
#     1. 2 - Seam Fastball
#     2. 4 - Seam Fastball
#     3. Changeup
#     4. Curveball
#     5. Cutter
#     6. Eephus
#     7. Knuckle Curve
#     8. Pitch Out
#     9. Sinker
#     10. Slider
#     11. Split Finger

# %% [markdown]
# # Key Attributes
# - Zone
# -https://baseballsavant.mlb.com/sections/statcast_search_v2/images/zones.png

# %% [markdown]
# # Data
# - Our data comes from BaseballSavant.com
# - This houses MLB's Statcast database, which tracks the ball's movement during every pitch and play.

# %%
#import packages to use for analysis
import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# reading the csv and loading it to source_data variable
# we do not have an index column 
# low_memory is needed because the file contains a lot of floats
source_data = pd.read_csv('2017_MLB_Data.csv', low_memory=False)

# %%
# collect number of rows and columns
rows = source_data.shape[0]
columns = source_data.shape[1]

print('Rows: ' + str(rows) + 'Cols: ' + str(columns))
# Out:
# Rows: 22695Cols: 89

# %%
# display columns missing data ratio
source_data.isna().mean().round(4) * 100
# Out:
# pitch_type               0.14
# game_date                0.00
# release_speed            0.23
# release_pos_x            0.23
# release_pos_z            0.23
#                          ...
# post_home_score          0.00
# post_bat_score           0.00
# post_fld_score           0.00
# if_fielding_alignment    0.26
# of_fielding_alignment    0.26
# Length: 89, dtype: float64

# %%
# drop columns that have more than 50% cells missing
drop_cols = source_data.columns[source_data.isnull().mean()>0.5]
source_data.drop(drop_cols, axis=1)
# Out:
#       pitch_type game_date  release_speed  release_pos_x  release_pos_z  \
# 0             FF   9/24/17           93.0        -0.6278         6.3865
# 1             FS   9/24/17           81.2        -0.9263         6.2440
# 2             FF   9/24/17           93.5        -0.5680         6.3990
# 3             FF   9/24/17           93.7        -0.7498         6.3757
# 4             FF   9/24/17           93.0        -0.8375         6.4247
# ...          ...       ...            ...            ...            ...
# 22690         FT    4/3/17           89.2         0.8567         6.0985
# 22691         FT    4/3/17           88.1         0.6802         6.1517
# 22692         FT    4/3/17           88.4         0.7248         6.0609
# 22693         FT    4/3/17           88.2         0.8767         6.1514
# 22694         FC    4/3/17           88.5         0.4774         6.1990
#
#        player_name  batter  pitcher      description  zone  ... home_score  \
# 0      Jose Altuve  514888   453284  swinging_strike   3.0  ...          5
# 1      Jose Altuve  514888   453284             ball  14.0  ...          5
# 2      Jose Altuve  514888   453284             ball  14.0  ...          5
# 3      Jose Altuve  514888   453284    called_strike   9.0  ...          5
# 4      Jose Altuve  514888   453284    called_strike   6.0  ...          5
# ...            ...     ...      ...              ...   ...  ...        ...
# 22690  Jean Segura  516416   572971             foul  13.0  ...          0
# 22691  Jean Segura  516416   572971    called_strike   7.0  ...          0
# 22692  Jean Segura  516416   572971             ball  13.0  ...          0
# 22693  Jean Segura  516416   572971             ball  14.0  ...          0
# 22694  Jean Segura  516416   572971             ball  14.0  ...          0
#
#       away_score bat_score fld_score post_away_score post_home_score  \
# 0              7         5         7               7               5
# 1              7         5         7               7               5
# 2              7         5         7               7               5
# 3              7         5         7               7               5
# 4              7         5         7               7               5
# ...          ...       ...       ...             ...             ...
# 22690          0         0         0               0               0
# 22691          0         0         0               0               0
# 22692          0         0         0               0               0
# 22693          0         0         0               0               0
# 22694          0         0         0               0               0
#
#        post_bat_score  post_fld_score  if_fielding_alignment  \
# 0                   5               7               Standard
# 1                   5               7               Standard
# 2                   5               7               Standard
# 3                   5               7               Standard
# 4                   5               7               Standard
# ...               ...             ...                    ...
# 22690               0               0              Strategic
# 22691               0               0              Strategic
# 22692               0               0              Strategic
# 22693               0               0              Strategic
# 22694               0               0              Strategic
#
#        of_fielding_alignment
# 0                  Strategic
# 1                  Strategic
# 2                  Strategic
# 3                  Strategic
# 4                  Strategic
# ...                      ...
# 22690               Standard
# 22691               Standard
# 22692               Standard
# 22693               Standard
# 22694               Standard
#
# [22695 rows x 62 columns]

# %%
#commented out until we impute columns
# source_data['Embarked_imputed'] = source_data['Embarked'].fillna(source_data['Embarked'].mode()[0])
# source_data['Age_imputed'] = source_data['Age'].fillna(source_data['Age'].mean())
# source_data.isnull().mean()*100
#
print('hello')

# %%
# checking the data types
source_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22695 entries, 0 to 22694
# Data columns (total 89 columns):
# pitch_type                         22664 non-null object
# game_date                          22695 non-null object
# release_speed                      22643 non-null float64
# release_pos_x                      22643 non-null float64
# release_pos_z                      22643 non-null float64
# player_name                        22695 non-null object
# batter                             22695 non-null int64
# pitcher                            22695 non-null int64
# events                             5836 non-null object
# description                        22695 non-null object
# spin_dir                           0 non-null float64
# spin_rate_deprecated               0 non-null float64
# break_angle_deprecated             0 non-null float64
# break_length_deprecated            0 non-null float64
# zone                               22643 non-null float64
# des                                5836 non-null object
# game_type                          22695 non-null object
# stand                              22695 non-null object
# p_throws                           22695 non-null object
# home_team                          22695 non-null object
# away_team                          22695 non-null object
# type                               22695 non-null object
# hit_location                       5094 non-null float64
# bb_type                            4021 non-null object
# balls                              22695 non-null int64
# strikes                            22695 non-null int64
# game_year                          22695 non-null int64
# pfx_x                              22643 non-null float64
# pfx_z                              22643 non-null float64
# plate_x                            22643 non-null float64
# plate_z                            22643 non-null float64
# on_3b                              2068 non-null float64
# on_2b                              4421 non-null float64
# on_1b                              6690 non-null float64
# outs_when_up                       22695 non-null int64
# inning                             22695 non-null int64
# inning_topbot                      22695 non-null object
# hc_x                               4005 non-null float64
# hc_y                               4005 non-null float64
# tfs_deprecated                     0 non-null float64
# tfs_zulu_deprecated                0 non-null float64
# fielder_2                          22675 non-null float64
# umpire                             0 non-null float64
# sv_id                              8529 non-null object
# vx0                                22643 non-null float64
# vy0                                22643 non-null float64
# vz0                                22643 non-null float64
# ax                                 22643 non-null float64
# ay                                 22643 non-null float64
# az                                 22643 non-null float64
# sz_top                             22675 non-null float64
# sz_bot                             22675 non-null float64
# hit_distance_sc                    5540 non-null float64
# launch_speed                       6073 non-null float64
# launch_angle                       6074 non-null float64
# effective_speed                    22257 non-null float64
# release_spin_rate                  22285 non-null float64
# release_extension                  22643 non-null float64
# game_pk                            22695 non-null int64
# pitcher.1                          22695 non-null int64
# fielder_2.1                        22675 non-null float64
# fielder_3                          22675 non-null float64
# fielder_4                          22675 non-null float64
# fielder_5                          22675 non-null float64
# fielder_6                          22675 non-null float64
# fielder_7                          22675 non-null float64
# fielder_8                          22675 non-null float64
# fielder_9                          22675 non-null float64
# release_pos_y                      22643 non-null float64
# estimated_ba_using_speedangle      4021 non-null float64
# estimated_woba_using_speedangle    4021 non-null float64
# woba_value                         5836 non-null float64
# woba_denom                         5836 non-null float64
# babip_value                        5836 non-null float64
# iso_value                          5836 non-null float64
# launch_speed_angle                 4021 non-null float64
# at_bat_number                      22695 non-null int64
# pitch_number                       22695 non-null int64
# pitch_name                         22664 non-null object
# home_score                         22695 non-null int64
# away_score                         22695 non-null int64
# bat_score                          22695 non-null int64
# fld_score                          22695 non-null int64
# post_away_score                    22695 non-null int64
# post_home_score                    22695 non-null int64
# post_bat_score                     22695 non-null int64
# post_fld_score                     22695 non-null int64
# if_fielding_alignment              22636 non-null object
# of_fielding_alignment              22636 non-null object
# dtypes: float64(52), int64(19), object(18)
# memory usage: 15.4+ MB

# %%
# displays basic statistics of the given data
source_data.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z         batter  \
# count   22643.000000   22643.000000   22643.000000   22695.000000
# mean       87.995235      -1.110656       5.931885  513236.633091
# std         6.012770       1.514586       0.476753  101091.776151
# min        64.800000      -4.989300       3.293000  134181.000000
# 25%        83.300000      -2.111500       5.637200  475174.000000
# 50%        88.900000      -1.504000       5.982900  514888.000000
# 75%        92.900000      -0.771750       6.265450  592743.000000
# max       102.400000       4.814300       7.150300  664057.000000
#
#              pitcher  spin_dir  spin_rate_deprecated  break_angle_deprecated  \
# count   22695.000000       0.0                   0.0                     0.0
# mean   543621.085217       NaN                   NaN                     NaN
# std     70691.374294       NaN                   NaN                     NaN
# min    112526.000000       NaN                   NaN                     NaN
# 25%    501789.000000       NaN                   NaN                     NaN
# 50%    571666.000000       NaN                   NaN                     NaN
# 75%    605242.000000       NaN                   NaN                     NaN
# max    664641.000000       NaN                   NaN                     NaN
#
#        break_length_deprecated          zone  ...  at_bat_number  \
# count                      0.0  22643.000000  ...   22695.000000
# mean                       NaN      9.624608  ...      38.433576
# std                        NaN      4.091088  ...      22.605053
# min                        NaN      1.000000  ...       1.000000
# 25%                        NaN      6.000000  ...      19.000000
# 50%                        NaN     11.000000  ...      38.000000
# 75%                        NaN     13.000000  ...      57.000000
# max                        NaN     14.000000  ...     108.000000
#
#        pitch_number    home_score    away_score     bat_score     fld_score  \
# count  22695.000000  22695.000000  22695.000000  22695.000000  22695.000000
# mean       2.905398      2.504781      1.970214      2.187927      2.287068
# std        1.738803      2.814522      2.254612      2.515007      2.611038
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.000000      0.000000
# 50%        3.000000      2.000000      1.000000      1.000000      1.000000
# 75%        4.000000      4.000000      3.000000      3.000000      3.000000
# max       13.000000     16.000000     13.000000     16.000000     16.000000
#
#        post_away_score  post_home_score  post_bat_score  post_fld_score
# count     22695.000000     22695.000000    22695.000000    22695.000000
# mean          1.970302         2.504781        2.188015        2.287068
# std           2.254770         2.814522        2.515141        2.611038
# min           0.000000         0.000000        0.000000        0.000000
# 25%           0.000000         0.000000        0.000000        0.000000
# 50%           1.000000         2.000000        1.000000        1.000000
# 75%           3.000000         4.000000        3.000000        3.000000
# max          13.000000        16.000000       16.000000       16.000000
#
# [8 rows x 71 columns]

# %%
# plots & displays a bar graph of the given column
ax = source_data.plot.bar(x='pitch_type')

# %%
# plots & displays a distrubtion chart of given columns
ax1 = source_data.groupby(['description']).sum().plot.bar(x='description', rot=0)

# %%
# plots & displays a distrubtion chart of given columns
ax2 = source_data['events'].plot(kind='hist')

# %%
# sex vs. survived
ax3 = source_data[['description', 'release_speed']].groupby(['description']).mean().plot(kind='bar', rot = 0)

# %%
# # sex vs. survived
ax4 = source_data.groupby('description')['release_speed'].value_counts().plot(kind='bar')

# %%
# #scatter plot
ax5 = source_data.plot.scatter(x='release_speed', y='release_pos_x', c='DarkBlue')

# %%
# scatter plot using seaborn
sns.lmplot('release_speed', 'release_pos_x', data=source_data, fit_reg=False)

# %%
# correlation chart
corr = source_data.loc[:,source_data.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))

# %% [markdown]
# # Research Answers
# 1. Which pitches were being hit most by Silver Slugger and All Star caliber players at Minute Maid Park in 2017?
#     -
# 2. Which pitch zones were Silver Slugger and All Star caliber players hitting pitches from?
#     -
# 3. How often did Astros players swing at pitches outside of the strike zone?
#     -
# 4. How did Astros players perform on breaking / offspeed pitches compared players from other teams?
#     -
# 5. Other comparisons between Astros players and opposing players.
#     -
